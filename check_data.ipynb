# %%
# dependencies
import numpy as np
import pandas as pd
from default.matplotlib_ import * # package loadaed

# %% [raw]
# <2년차> 내용정리
#
# 정식날짜: 2021년 9월 14일
# 정식주수: (108주*10베드) + (106주*5베드) + 번외 = 1,922주
#             - 번외: 104주*3베드 = 312주
# 배액 EC 변경 날짜: 2021년 11월 3일
# 생육조사: 1달에 1번, 10개체 3반복
#   (초장, 엽장, 엽폭, 엽병장, 경경)
# 품질조사: 7일에 1번(익으면 2번), 20개체 3반복
#   (상품과, 비상품과 수, 무게)
# 수확조사: 1달에 1번, 10개체 3반복
#   (과중, 과고, 과폭, 당도, 경도)
# 식물체분석, 산도 등
# 처리내용: 배액 EC 3처리(1: 0.6, 2: 0.9, 3: 1.2), 4: 전량

# %%
df = pd.read_excel("./data/in_out_ion.xlsx")
df.set_index("Label", inplace = True)
df.head()
# 대량원소, 미량원소
# 과다가 문제가 되는 원소, 결핍이 문제가 되는 원소
# 대량원소 = NH4, NO3, P, K, Ca, Mg, S, Na, Cl, HCO3
# 미량원소 = Fe, Mn, B, Zn, Cu, Mo
# Out:
#             date   급액1   급액2   급액3   급액4  배액1-1  배액1-2 배액1-3  배액2-1  배액2-2  \
# Label
# NH4   2021-11-17  7.01  6.07  5.60  6.54   1.87   0.93  0.93   1.40   1.40
# NH4   2021-12-02  8.41  7.01  7.01  5.60   1.87   2.80   1.4   1.87   1.40
# NH4   2021-12-17  4.67  3.27  1.87  3.74   1.87   2.80  1.87   2.80   0.93
# NH4   2021-12-30  3.27  1.87  1.87  1.87   0.93   1.40  0.93   0.93   0.93
# NH4   2022-01-13  0.93  0.93  0.93  0.93   0.93   0.93  1.87   1.87   1.87
#
#        배액2-3  배액3-1  배액3-2  배액3-3  배액4-1  배액4-2  배액4-3
# Label
# NH4     0.93   1.87   0.93   1.40   0.93   0.93   0.93
# NH4     1.87   1.87   2.34   1.87   1.87   1.87   1.87
# NH4     1.87   0.93   1.87   0.93   1.87   0.93   1.40
# NH4     1.87   0.93   0.93   0.93   0.93   0.93   0.93
# NH4     1.40   1.40   1.87   1.40   0.93   1.87   1.87

# %%
NH4 = df.loc[:, ['date', '급액1', '급액2', '급액3', '급액4']].loc["NH4"]
NO3 = df.loc[:, ['date', '급액1', '급액2', '급액3', '급액4']].loc["NO3"]
P = df.loc[:, ['date', '급액1', '급액2', '급액3', '급액4']].loc["P"]
K = df.loc[:, ['date', '급액1', '급액2', '급액3', '급액4']].loc["K"]
Ca = df.loc[:, ['date', '급액1', '급액2', '급액3', '급액4']].loc["Ca"]
Mg = df.loc[:, ['date', '급액1', '급액2', '급액3', '급액4']].loc["Mg"]
S = df.loc[:, ['date', '급액1', '급액2', '급액3', '급액4']].loc["S"]

# %%
fig = plt.figure(figsize=(10, 3.5), layout="constrained")
spec = fig.add_gridspec(ncols=4, nrows=2)

ax0 = fig.add_subplot(spec[0, 0])
ax0.plot(NH4.date, NH4['급액1'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')
ax0.plot(NH4.date, NH4['급액2'], 'o-', markersize = 2, c = cmap[1], label = 'EC 0.9')
ax0.plot(NH4.date, NH4['급액3'], 'o-', markersize = 2, c = cmap[2], label = 'EC 1.2')
ax0.plot(NH4.date, NH4['급액4'], 'o-', markersize = 2, c = cmap[3], label = 'All use')

ax1 = fig.add_subplot(spec[0, 1])
ax1.plot(NO3.date, NO3['급액1'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')
ax1.plot(NO3.date, NO3['급액2'], 'o-', markersize = 2, c = cmap[1], label = 'EC 0.9')
ax1.plot(NO3.date, NO3['급액3'], 'o-', markersize = 2, c = cmap[2], label = 'EC 1.2')
ax1.plot(NO3.date, NO3['급액4'], 'o-', markersize = 2, c = cmap[3], label = 'All use')

ax2 = fig.add_subplot(spec[1, 0])
ax2.plot(P.date, P['급액1'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')
ax2.plot(P.date, P['급액2'], 'o-', markersize = 2, c = cmap[1], label = 'EC 0.9')
ax2.plot(P.date, P['급액3'], 'o-', markersize = 2, c = cmap[2], label = 'EC 1.2')
ax2.plot(P.date, P['급액4'], 'o-', markersize = 2, c = cmap[3], label = 'All use')

ax3 = fig.add_subplot(spec[1, 1])
ax3.plot(K.date, K['급액1'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')
ax3.plot(K.date, K['급액2'], 'o-', markersize = 2, c = cmap[1], label = 'EC 0.9')
ax3.plot(K.date, K['급액3'], 'o-', markersize = 2, c = cmap[2], label = 'EC 1.2')
ax3.plot(K.date, K['급액4'], 'o-', markersize = 2, c = cmap[3], label = 'All use')

ax4 = fig.add_subplot(spec[0, 2])
ax4.plot(Ca.date, Ca['급액1'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')
ax4.plot(Ca.date, Ca['급액2'], 'o-', markersize = 2, c = cmap[1], label = 'EC 0.9')
ax4.plot(Ca.date, Ca['급액3'], 'o-', markersize = 2, c = cmap[2], label = 'EC 1.2')
ax4.plot(Ca.date, Ca['급액4'], 'o-', markersize = 2, c = cmap[3], label = 'All use')


ax5 = fig.add_subplot(spec[1, 2])
ax5.plot(Mg.date, Mg['급액1'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')
ax5.plot(Mg.date, Mg['급액2'], 'o-', markersize = 2, c = cmap[1], label = 'EC 0.9')
ax5.plot(Mg.date, Mg['급액3'], 'o-', markersize = 2, c = cmap[2], label = 'EC 1.2')
ax5.plot(Mg.date, Mg['급액4'], 'o-', markersize = 2, c = cmap[3], label = 'All use')

ax6 = fig.add_subplot(spec[1, 3])
ax6.plot(S.date, S['급액1'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')
ax6.plot(S.date, S['급액2'], 'o-', markersize = 2, c = cmap[1], label = 'EC 0.9')
ax6.plot(S.date, S['급액3'], 'o-', markersize = 2, c = cmap[2], label = 'EC 1.2')
ax6.plot(S.date, S['급액4'], 'o-', markersize = 2, c = cmap[3], label = 'All use')

ax6.legend(frameon = False, loc = [0, 0.5])

title = ['NH4', 'NO3', 'P', 'K', 'Ca', 'Mg', 'S']
for i, ax in enumerate([ax0, ax1, ax2, ax3, ax4, ax5, ax6]):
    # Set the title of the current subplot using the corresponding title from the list
    ax.set_title(title[i])
    #ax.set_ylim([0, 150])

fig.autofmt_xdate(rotation=30)
fig.suptitle('Major Nutrients, input')

plt.savefig('./figs_/Major_input.pdf', dpi=300, format='pdf', bbox_inches='tight')
# Out:
# /var/folders/s0/6fg4kkm534vgnh5rxk70ljkc0000gn/T/ipykernel_5349/4236674978.py:55: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.autofmt_xdate(rotation=30)

# %%
NH4_ec06 = df.loc[:, ['date', '배액1-1', '배액1-2', '배액1-3']].loc["NH4"]
NO3_ec06 = df.loc[:, ['date', '배액1-1', '배액1-2', '배액1-3']].loc["NO3"]
P_ec06 = df.loc[:, ['date', '배액1-1', '배액1-2', '배액1-3']].loc["P"]
K_ec06 = df.loc[:, ['date', '배액1-1', '배액1-2', '배액1-3']].loc["K"]
Ca_ec06 = df.loc[:, ['date', '배액1-1', '배액1-2', '배액1-3']].loc["Ca"]
Mg_ec06 = df.loc[:, ['date', '배액1-1', '배액1-2', '배액1-3']].loc["Mg"]
S_ec06 = df.loc[:, ['date', '배액1-1', '배액1-2', '배액1-3']].loc["S"]
################################
NH4_ec09 = df.loc[:, ['date', '배액2-1', '배액2-2', '배액2-3']].loc["NH4"]
NO3_ec09 = df.loc[:, ['date', '배액2-1', '배액2-2', '배액2-3']].loc["NO3"]
P_ec09 = df.loc[:, ['date', '배액2-1', '배액2-2', '배액2-3']].loc["P"]
K_ec09 = df.loc[:, ['date', '배액2-1', '배액2-2', '배액2-3']].loc["K"]
Ca_ec09 = df.loc[:, ['date', '배액2-1', '배액2-2', '배액2-3']].loc["Ca"]
Mg_ec09 = df.loc[:, ['date', '배액2-1', '배액2-2', '배액2-3']].loc["Mg"]
S_ec09 = df.loc[:, ['date', '배액2-1', '배액2-2', '배액2-3']].loc["S"]
################################
NH4_ec12 = df.loc[:, ['date', '배액3-1', '배액3-2', '배액3-3']].loc["NH4"]
NO3_ec12 = df.loc[:, ['date', '배액3-1', '배액3-2', '배액3-3']].loc["NO3"]
P_ec12 = df.loc[:, ['date', '배액3-1', '배액3-2', '배액3-3']].loc["P"]
K_ec12 = df.loc[:, ['date', '배액3-1', '배액3-2', '배액3-3']].loc["K"]
Ca_ec12 = df.loc[:, ['date', '배액3-1', '배액3-2', '배액3-3']].loc["Ca"]
Mg_ec12 = df.loc[:, ['date', '배액3-1', '배액3-2', '배액3-3']].loc["Mg"]
S_ec12 = df.loc[:, ['date', '배액3-1', '배액3-2', '배액3-3']].loc["S"]
################################
NH4_all = df.loc[:, ['date', '배액4-1', '배액4-2', '배액4-3']].loc["NH4"]
NO3_all = df.loc[:, ['date', '배액4-1', '배액4-2', '배액4-3']].loc["NO3"]
P_all = df.loc[:, ['date', '배액4-1', '배액4-2', '배액4-3']].loc["P"]
K_all = df.loc[:, ['date', '배액4-1', '배액4-2', '배액4-3']].loc["K"]
Ca_all = df.loc[:, ['date', '배액4-1', '배액4-2', '배액4-3']].loc["Ca"]
Mg_all = df.loc[:, ['date', '배액4-1', '배액4-2', '배액4-3']].loc["Mg"]
S_all = df.loc[:, ['date', '배액4-1', '배액4-2', '배액4-3']].loc["S"]

# %%
fig = plt.figure(figsize=(10, 3.5), layout="constrained")
spec = fig.add_gridspec(ncols=4, nrows=2)

ax0 = fig.add_subplot(spec[0, 0])
ax0.plot(NH4_ec06.date, NH4_ec06['배액1-1'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')
ax0.plot(NH4_ec06.date, NH4_ec06['배액1-2'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')
ax0.plot(NH4_ec06.date, NH4_ec06['배액1-3'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')

ax0.plot(NH4_ec09.date, NH4_ec09['배액2-1'], 'o-', markersize = 2, c = cmap[2], label = 'EC 0.9')
ax0.plot(NH4_ec09.date, NH4_ec09['배액2-2'], 'o-', markersize = 2, c = cmap[2], label = 'EC 0.9')
ax0.plot(NH4_ec09.date, NH4_ec09['배액2-3'], 'o-', markersize = 2, c = cmap[2], label = 'EC 0.9')

ax0.plot(NH4_ec12.date, NH4_ec12['배액3-1'], 'o-', markersize = 2, c = cmap[3], label = 'EC 1.2')
ax0.plot(NH4_ec12.date, NH4_ec12['배액3-2'], 'o-', markersize = 2, c = cmap[3], label = 'EC 1.2')
ax0.plot(NH4_ec12.date, NH4_ec12['배액3-3'], 'o-', markersize = 2, c = cmap[3], label = 'EC 1.2')

ax0.plot(NH4_all.date, NH4_all['배액4-1'], 'o-', markersize = 2, c = cmap[4], label = 'All use')
ax0.plot(NH4_all.date, NH4_all['배액4-2'], 'o-', markersize = 2, c = cmap[4], label = 'All use')
ax0.plot(NH4_all.date, NH4_all['배액4-3'], 'o-', markersize = 2, c = cmap[4], label = 'All use')

ax1 = fig.add_subplot(spec[0, 1])
ax1.plot(NO3_ec06.date, NO3_ec06['배액1-2'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')
ax1.plot(NO3_ec06.date, NO3_ec06['배액1-1'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')
ax1.plot(NO3_ec06.date, NO3_ec06['배액1-3'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')

ax1.plot(NO3_ec09.date, NO3_ec09['배액2-1'], 'o-', markersize = 2, c = cmap[2], label = 'EC 0.9')
ax1.plot(NO3_ec09.date, NO3_ec09['배액2-2'], 'o-', markersize = 2, c = cmap[2], label = 'EC 0.9')
ax1.plot(NO3_ec09.date, NO3_ec09['배액2-3'], 'o-', markersize = 2, c = cmap[2], label = 'EC 0.9')

ax1.plot(NO3_ec12.date, NO3_ec12['배액3-1'], 'o-', markersize = 2, c = cmap[3], label = 'EC 1.2')
ax1.plot(NO3_ec12.date, NO3_ec12['배액3-2'], 'o-', markersize = 2, c = cmap[3], label = 'EC 1.2')
ax1.plot(NO3_ec12.date, NO3_ec12['배액3-3'], 'o-', markersize = 2, c = cmap[3], label = 'EC 1.2')

ax1.plot(NO3_all.date, NO3_all['배액4-1'], 'o-', markersize = 2, c = cmap[4], label = 'All use')
ax1.plot(NO3_all.date, NO3_all['배액4-2'], 'o-', markersize = 2, c = cmap[4], label = 'All use')
ax1.plot(NO3_all.date, NO3_all['배액4-3'], 'o-', markersize = 2, c = cmap[4], label = 'All use')

ax2 = fig.add_subplot(spec[1, 0])
ax2.plot(P_ec06.date, P_ec06['배액1-2'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')
ax2.plot(P_ec06.date, P_ec06['배액1-1'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')
ax2.plot(P_ec06.date, P_ec06['배액1-3'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')

ax2.plot(P_ec09.date, P_ec09['배액2-1'], 'o-', markersize = 2, c = cmap[2], label = 'EC 0.9')
ax2.plot(P_ec09.date, P_ec09['배액2-2'], 'o-', markersize = 2, c = cmap[2], label = 'EC 0.9')
ax2.plot(P_ec09.date, P_ec09['배액2-3'], 'o-', markersize = 2, c = cmap[2], label = 'EC 0.9')

ax2.plot(P_ec12.date, P_ec12['배액3-1'], 'o-', markersize = 2, c = cmap[3], label = 'EC 1.2')
ax2.plot(P_ec12.date, P_ec12['배액3-2'], 'o-', markersize = 2, c = cmap[3], label = 'EC 1.2')
ax2.plot(P_ec12.date, P_ec12['배액3-3'], 'o-', markersize = 2, c = cmap[3], label = 'EC 1.2')

ax2.plot(P_all.date, P_all['배액4-1'], 'o-', markersize = 2, c = cmap[4], label = 'All use')
ax2.plot(P_all.date, P_all['배액4-2'], 'o-', markersize = 2, c = cmap[4], label = 'All use')
ax2.plot(P_all.date, P_all['배액4-3'], 'o-', markersize = 2, c = cmap[4], label = 'All use')

ax3 = fig.add_subplot(spec[1, 1])
ax3.plot(K_ec06.date, K_ec06['배액1-2'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')
ax3.plot(K_ec06.date, K_ec06['배액1-1'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')
ax3.plot(K_ec06.date, K_ec06['배액1-3'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')

ax3.plot(K_ec09.date, K_ec09['배액2-1'], 'o-', markersize = 2, c = cmap[2], label = 'EC 0.9')
ax3.plot(K_ec09.date, K_ec09['배액2-2'], 'o-', markersize = 2, c = cmap[2], label = 'EC 0.9')
ax3.plot(K_ec09.date, K_ec09['배액2-3'], 'o-', markersize = 2, c = cmap[2], label = 'EC 0.9')

ax3.plot(K_ec12.date, K_ec12['배액3-1'], 'o-', markersize = 2, c = cmap[3], label = 'EC 1.2')
ax3.plot(K_ec12.date, K_ec12['배액3-2'], 'o-', markersize = 2, c = cmap[3], label = 'EC 1.2')
ax3.plot(K_ec12.date, K_ec12['배액3-3'], 'o-', markersize = 2, c = cmap[3], label = 'EC 1.2')

ax3.plot(K_all.date, K_all['배액4-1'], 'o-', markersize = 2, c = cmap[4], label = 'All use')
ax3.plot(K_all.date, K_all['배액4-2'], 'o-', markersize = 2, c = cmap[4], label = 'All use')
ax3.plot(K_all.date, K_all['배액4-3'], 'o-', markersize = 2, c = cmap[4], label = 'All use')

ax4 = fig.add_subplot(spec[0, 2])
ax4.plot(Ca_ec06.date, Ca_ec06['배액1-2'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')
ax4.plot(Ca_ec06.date, Ca_ec06['배액1-1'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')
ax4.plot(Ca_ec06.date, Ca_ec06['배액1-3'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')

ax4.plot(Ca_ec09.date, Ca_ec09['배액2-1'], 'o-', markersize = 2, c = cmap[2], label = 'EC 0.9')
ax4.plot(Ca_ec09.date, Ca_ec09['배액2-2'], 'o-', markersize = 2, c = cmap[2], label = 'EC 0.9')
ax4.plot(Ca_ec09.date, Ca_ec09['배액2-3'], 'o-', markersize = 2, c = cmap[2], label = 'EC 0.9')

ax4.plot(Ca_ec12.date, Ca_ec12['배액3-1'], 'o-', markersize = 2, c = cmap[3], label = 'EC 1.2')
ax4.plot(Ca_ec12.date, Ca_ec12['배액3-2'], 'o-', markersize = 2, c = cmap[3], label = 'EC 1.2')
ax4.plot(Ca_ec12.date, Ca_ec12['배액3-3'], 'o-', markersize = 2, c = cmap[3], label = 'EC 1.2')

ax4.plot(Ca_all.date,  Ca_all['배액4-1'], 'o-', markersize = 2, c = cmap[4], label = 'All use')
ax4.plot(Ca_all.date,  Ca_all['배액4-2'], 'o-', markersize = 2, c = cmap[4], label = 'All use')
ax4.plot(Ca_all.date,  Ca_all['배액4-3'], 'o-', markersize = 2, c = cmap[4], label = 'All use')

ax5 = fig.add_subplot(spec[1, 2])
ax5.plot(Mg_ec06.date, Mg_ec06['배액1-2'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')
ax5.plot(Mg_ec06.date, Mg_ec06['배액1-1'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')
ax5.plot(Mg_ec06.date, Mg_ec06['배액1-3'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')

ax5.plot(Mg_ec09.date, Mg_ec09['배액2-1'], 'o-', markersize = 2, c = cmap[2], label = 'EC 0.9')
ax5.plot(Mg_ec09.date, Mg_ec09['배액2-2'], 'o-', markersize = 2, c = cmap[2], label = 'EC 0.9')
ax5.plot(Mg_ec09.date, Mg_ec09['배액2-3'], 'o-', markersize = 2, c = cmap[2], label = 'EC 0.9')

ax5.plot(Mg_ec12.date, Mg_ec12['배액3-1'], 'o-', markersize = 2, c = cmap[3], label = 'EC 1.2')
ax5.plot(Mg_ec12.date, Mg_ec12['배액3-2'], 'o-', markersize = 2, c = cmap[3], label = 'EC 1.2')
ax5.plot(Mg_ec12.date, Mg_ec12['배액3-3'], 'o-', markersize = 2, c = cmap[3], label = 'EC 1.2')

ax5.plot(Mg_all.date,  Mg_all['배액4-1'], 'o-', markersize = 2, c = cmap[4], label = 'All use')
ax5.plot(Mg_all.date,  Mg_all['배액4-2'], 'o-', markersize = 2, c = cmap[4], label = 'All use')
ax5.plot(Mg_all.date,  Mg_all['배액4-3'], 'o-', markersize = 2, c = cmap[4], label = 'All use')

ax6 = fig.add_subplot(spec[1, 3])
ax6.plot(S_ec06.date, S_ec06['배액1-2'], 'o-', markersize = 2, c = cmap[0], label = 'EC 0.6')
ax6.plot(S_ec06.date, S_ec06['배액1-1'], 'o-', markersize = 2, c = cmap[0],)
ax6.plot(S_ec06.date, S_ec06['배액1-3'], 'o-', markersize = 2, c = cmap[0],)

ax6.plot(S_ec09.date, S_ec09['배액2-1'], 'o-', markersize = 2, c = cmap[2], label = 'EC 0.9')
ax6.plot(S_ec09.date, S_ec09['배액2-2'], 'o-', markersize = 2, c = cmap[2],)
ax6.plot(S_ec09.date, S_ec09['배액2-3'], 'o-', markersize = 2, c = cmap[2],)

ax6.plot(S_ec12.date, S_ec12['배액3-1'], 'o-', markersize = 2, c = cmap[3], label = 'EC 1.2')
ax6.plot(S_ec12.date, S_ec12['배액3-2'], 'o-', markersize = 2, c = cmap[3],)
ax6.plot(S_ec12.date, S_ec12['배액3-3'], 'o-', markersize = 2, c = cmap[3],)

ax6.plot(S_all.date,  S_all['배액4-1'], 'o-', markersize = 2, c = cmap[4], label = 'All use')
ax6.plot(S_all.date,  S_all['배액4-2'], 'o-', markersize = 2, c = cmap[4],)
ax6.plot(S_all.date,  S_all['배액4-3'], 'o-', markersize = 2, c = cmap[4],)

ax6.legend(frameon = False, loc = [0, 0.5])

title = ['NH4', 'NO3', 'P', 'K', 'Ca', 'Mg', 'S']
for i, ax in enumerate([ax0, ax1, ax2, ax3, ax4, ax5, ax6]):
    # Set the title of the current subplot using the corresponding title from the list
    ax.set_title(title[i])
    #ax.set_ylim([0, 150])

fig.autofmt_xdate(rotation=30)
fig.suptitle('Major Nutrients, output')

plt.savefig('./figs_/Major_Output.pdf', dpi=300, format='pdf', bbox_inches='tight')
# Out:
# /var/folders/s0/6fg4kkm534vgnh5rxk70ljkc0000gn/T/ipykernel_5349/232193392.py:131: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.autofmt_xdate(rotation=30)
